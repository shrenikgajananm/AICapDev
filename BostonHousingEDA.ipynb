# %%
import pandas as pd

# %% [markdown]
# ### Step-1: Load the Dataset
# ##### Most essential process, can't work without data :(

# %%
df = pd.read_csv("HousingData.csv")

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# ### Step-2: Understand the Dataset Structure
# ##### This provides a quick overview of the dataset's structure, helping identify potential issues early on, like the number of rows and columns, which are crucial for understanding dataset size and feasibility for analysis. df.info() reveals column names, data types, and missing values, allowing us to detect incorrect data types (e.g., numbers stored as strings) and assess data completeness

# %%
row, column = df.shape
print("Total Rows are", row)
print("Total Columns are", column)
# Out:
# Total Rows are 506
# Total Columns are 14

# %%
columns = df.columns
print("Column names are as follows\n")
for column in columns:
    print(column, end = ", ")
# Out:
# Column names are as follows
#
# CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, MEDV,

# %%
print("Dataset structure including column names, data types, and non-null counts are as follows\n")
df.info()
# Out:
# Dataset structure including column names, data types, and non-null counts are as follows
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %% [markdown]
# ## Step-3: Dataset Statistics
# ##### This provides summary statistics for numerical columns, highlighting value distributions, possible outliers, and missing trends. These insights help in deciding necessary preprocessing steps, optimizing memory usage, and ensuring data integrity before deeper analysis.

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# ## Step-4: Check Anomalies in Dataset
# ##### Checking for anomalies is required because anomalies—such as missing values, duplicates, outliers, and inconsistent data—can distort analysis, lead to misleading conclusions, and negatively impact machine learning models. It may also introduce bias or reduce model performance if not handled properly.
# ##### Similarly, Duplicates can inflate trends, leading to incorrect insights.
# ##### Outliers are extreme values that may affect model performance, the skewness shows if features are symmetrically distributed or need transformations. This helps in data cleaning to decide whether to remove, cap, or transform outliers before model training.

# %%
print("Total missing values from each column are as follows\n")
df.isnull().sum()
# Out:
# Total missing values from each column are as follows
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
print("Total number of duplicate rows are as follows\n")
df.duplicated().sum()
# Out:
# Total number of duplicate rows are as follows
# np.int64(0)

# %%
df.boxplot()
plt.show()

# %% [markdown]
# Black Circles indicates the ouliers which are extreme values that deviate significantly from the majority of the data
#
# Green Line is for median values for each column, the green line inside boxes is not centered in some boxes, suggesting skewness in the data distribution
#
# Whiskers or the blue boxes gives the range of data, longer whiskers indicates high variance in the data
